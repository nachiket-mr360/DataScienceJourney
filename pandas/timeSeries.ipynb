# %%
''' 
converting columns to datetime
use pd.to_datetime() to convert strings or numbers into datetime objects
once converted, pandas recognizes them as dates, enabling powerful operations'''
import pandas as pd
data = {
    'orderID':[1001,1002,1003,1004,1005],
    'orderdate':['2024-01-05','2024/01/12','15-01-2024','2024-01-20','20240125'],
    'customer':['alice','bob','charlie','david','emma'],
    'amount':[250,400,150,300,500]
    
}
df = pd.DataFrame(data)
df
# Out:
#    orderID   orderdate customer  amount
# 0     1001  2024-01-05    alice     250
# 1     1002  2024/01/12      bob     400
# 2     1003  15-01-2024  charlie     150
# 3     1004  2024-01-20    david     300
# 4     1005    20240125     emma     500

# %%
df.dtypes
# Out:
# orderID       int64
# orderdate    object
# customer     object
# amount        int64
# dtype: object

# %%
pd.to_datetime(df['orderdate']) #we must convert the date in a format to apply changes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pd.to_datetime(df['orderdate'])
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
# ...

# %%
df['orderdate'] = pd.to_datetime(df['orderdate'],errors='coerce') #remove errored data and give unerrored data

# %%
''' 
2.setting datetime index and resampling
* set a datetime column as the index with set_index(),
* resample time series using resample('M').mean() or other rules ('D','W','Y')
useful for aggregating data by time periods.
'''
df_idex = df.set_index("orderdate")
df_idex
# Out:
#             orderID customer  amount
# orderdate
# 2024-01-05     1001    alice     250
# NaT            1002      bob     400
# NaT            1003  charlie     150
# 2024-01-20     1004    david     300
# NaT            1005     emma     500

# %%
df_idex.resample('M')['amount'].sum()
# Out:
# C:\Users\nachi\AppData\Local\Temp\ipykernel_5072\1064612877.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_idex.resample('M')['amount'].sum()
# orderdate
# 2024-01-31    550
# Name: amount, dtype: int64
