# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('hotel_bookings.csv')
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
print(df.isna())
#true means missing value present false me no missing values we can also use 
print(df.isnull())
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
#to get the sum we add sum function 
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#to drop a missing values
#before drop we will copy the actual file and edit the copied files 
df_copy = df
df_copy
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df_copy.dropna()
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2392    Resort Hotel            0          6               2015
# 2697    Resort Hotel            0         24               2015
# 2867    Resort Hotel            0         24               2015
# 2877    Resort Hotel            0         24               2015
# 2878    Resort Hotel            0         24               2015
# ...              ...          ...        ...                ...
# 112499    City Hotel            0         13               2017
# 113046    City Hotel            0         13               2017
# 113082    City Hotel            0         13               2017
# 113627    City Hotel            0        210               2017
# 116451    City Hotel            0        191               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2392              October                        42
# 2697              October                        44
# ...

# %%
#as we see there is huge data we lost because of missing values so droping the data is not a proper option
#before droping we need to understand the data and drop it. we can replace it.

# %%
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.agent.isnull().sum()
# Out:
# 16340

# %%
df['agent'].unique()
# Out:
# array([ nan, 304., 240., 303.,  15., 241.,   8., 250., 115.,   5., 175.,
#        134., 156., 243., 242.,   3., 105.,  40., 147., 306., 184.,  96.,
#          2., 127.,  95., 146.,   9., 177.,   6., 143., 244., 149., 167.,
#        300., 171., 305.,  67., 196., 152., 142., 261., 104.,  36.,  26.,
#         29., 258., 110.,  71., 181.,  88., 251., 275.,  69., 248., 208.,
#        256., 314., 126., 281., 273., 253., 185., 330., 334., 328., 326.,
#        321., 324., 313.,  38., 155.,  68., 335., 308., 332.,  94., 348.,
#        310., 339., 375.,  66., 327., 387., 298.,  91., 245., 385., 257.,
#        393., 168., 405., 249., 315.,  75., 128., 307.,  11., 436.,   1.,
#        201., 183., 223., 368., 336., 291., 464., 411., 481.,  10., 154.,
#        468., 410., 390., 440., 495., 492., 493., 434.,  57., 531., 420.,
#        483., 526., 472., 429.,  16., 446.,  34.,  78., 139., 252., 270.,
#         47., 114., 301., 193., 182., 135., 350., 195., 352., 355., 159.,
# ...

# %%
df['agent'].mean()
# Out:
# 86.69338185346919

# %%
df['agent'].median()
# Out:
# 14.0

# %%
df['agent'].mode()
# Out:
# 0    9.0
# Name: agent, dtype: float64

# %%
#we can fill those using mean, mode and median and also fill using forward and backward fill methods
df['agent'] = df['agent'].fillna(method='bfill')
df['agent'].isnull().sum()
# Out:
# C:\Users\nachi\AppData\Local\Temp\ipykernel_10400\3628503596.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['agent'] = df['agent'].fillna(method='bfill')
# 0

# %%
df['company'].isnull().sum()
# Out:
# 112593

# %%
df.company.unique()
# Out:
# array([ nan, 110., 113., 270., 178., 240., 154., 144., 307., 268.,  59.,
#        204., 312., 318.,  94., 174., 274., 195., 223., 317., 281., 118.,
#         53., 286.,  12.,  47., 324., 342., 373., 371., 383.,  86.,  82.,
#        218.,  88.,  31., 397., 392., 405., 331., 367.,  20.,  83., 416.,
#         51., 395., 102.,  34.,  84., 360., 394., 457., 382., 461., 478.,
#        386., 112., 486., 421.,   9., 308., 135., 224., 504., 269., 356.,
#        498., 390., 513., 203., 263., 477., 521., 169., 515., 445., 337.,
#        251., 428., 292., 388., 130., 250., 355., 254., 543., 531., 528.,
#         62., 120.,  42.,  81., 116., 530., 103.,  39.,  16.,  92.,  61.,
#        501., 165., 291., 290.,  43., 325., 192., 108., 200., 465., 287.,
#        297., 490., 482., 207., 282., 437., 225., 329., 272.,  28.,  77.,
#        338.,  72., 246., 319., 146., 159., 380., 323., 511., 407., 278.,
#         80., 403., 399.,  14., 137., 343., 346., 347., 349., 289., 351.,
# ...

# %%
df['company'] = df['company'].fillna(df['company'].mean())

# %%
df['company']
# Out:
# 0         189.266735
# 1         189.266735
# 2         189.266735
# 3         189.266735
# 4         189.266735
#              ...
# 119385    189.266735
# 119386    189.266735
# 119387    189.266735
# 119388    189.266735
# 119389    189.266735
# Name: company, Length: 119390, dtype: float64

# %%
df.isnull().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            4
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# agent                               0
# company                             0
# ...

# %%
df['country'].value_counts()
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: count, Length: 177, dtype: int64

# %%
df['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
df['country'] = df['company'].fillna(df['country'].mode())
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          4
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
#to change the dtype of any column
#first know the data types 
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                           float64
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
#replace the values 
df_copy
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
a = {
    'Name':['alice','bob','charlie','david','emma'],
    'Age':[25,30,35,40,22],
    'Score':[88,92,79,85,95]}
b = pd.DataFrame(data=a)
b
# Out:
#       Name  Age  Score
# 0    alice   25     88
# 1      bob   30     92
# 2  charlie   35     79
# 3    david   40     85
# 4     emma   22     95

# %%
b['Score'] = b['Score'].astype(float) #to change dtype of any column

# %%
b
# Out:
#       Name  Age  Score
# 0    alice   25   88.0
# 1      bob   30   92.0
# 2  charlie   35   79.0
# 3    david   40   85.0
# 4     emma   22   95.0

# %%
#to replace
b['Name'] = b['Name'].replace('bob', 'Robert')

# %%
b['Name']
# Out:
# 0      alice
# 1     Robert
# 2    charlie
# 3      david
# 4       emma
# Name: Name, dtype: object

# %%
b['Score'] = b['Score'].replace({88.0:90.0, 95.0:99.0}) #for changing multiple values

# %%
b
# Out:
#       Name  Age  Score
# 0    alice   25   90.0
# 1   Robert   30   92.0
# 2  charlie   35   79.0
# 3    david   40   85.0
# 4     emma   22   99.0

# %%
b.dtypes
# Out:
# Name      object
# Age        int64
# Score    float64
# dtype: object

# %%
#dropping row and columns
c = b

# %%
#c.drop(labels, axis)
c.drop(['Name'], axis=1) #axis 1 is for column , we not used implace =treu hence it nor permanent
# Out:
#    Age  Score
# 0   25   90.0
# 1   30   92.0
# 2   35   79.0
# 3   40   85.0
# 4   22   99.0

# %%
c.drop(1, axis=0, inplace=True)

# %%
c.drop(3, inplace=True) #bydefault axis is 0

# %%
c
# Out:
#       Name  Age  Score
# 0    alice   25   90.0
# 2  charlie   35   79.0
# 4     emma   22   99.0

# %%
#deleting and removing duplicates
data = {
    'Name':['alice','bob','charlie','alice', 'bob','david'],
    'age':[25,30,35,34,30,40],
    'score':[88,92,79,88,92,95]
}
df = pd.DataFrame(data)

# %%
df.duplicated() #all the row must have same values then only it considered as duplicated if one value also changed then it not
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       Name  age  score
# 0    alice   25     88
# 1      bob   30     92
# 2  charlie   35     79
# 3    alice   34     88
# 5    david   40     95

# %%
import pandas as pd
import numpy as np

# 1. Create a messy DataFrame
data = {
    "Name": ["Alice", "Bob", "Chrlie", "David", "Alice", None],
    "Age": ["25", "30", None, "40", "25", "30"],      # ages stored as strings, with missing value
    "City": ["Delhi", "Mumbai", "Pun", "Bangalore", "Delhi", "Mumbai"],  # typo: "Pun" -> "Pune"
    "Score": [85, None, 78, 88, 85, 91],              # missing value in Score
    "Extra": ["x", "y", "z", "x", "y", "z"]           # extra column we don't really need
}

df = pd.DataFrame(data)

print("Original messy DataFrame:")
print(df)

# 2. Handle missing values
# Fill or drop as needed

# 3. Change data types
# Convert Age to int, Score to float, etc.

# 4. Replace incorrect values
# Fix 'Pun' -> 'Pune', maybe unify Name spellings if needed

# 5. Drop unnecessary rows/columns
# Remove 'Extra' or any row you don't want

# 6. Remove duplicates
# Use duplicated() and drop_duplicates()

# 7. Final clean DataFrame
# Print the cleaned DataFrame and check info()
# Out:
# Original messy DataFrame:
#      Name   Age       City  Score Extra
# 0   Alice    25      Delhi   85.0     x
# 1     Bob    30     Mumbai    NaN     y
# 2  Chrlie  None        Pun   78.0     z
# 3   David    40  Bangalore   88.0     x
# 4   Alice    25      Delhi   85.0     y
# 5    None    30     Mumbai   91.0     z

# %%
#2handle missing values 
df.isnull().sum()
# Out:
# Name     1
# Age      1
# City     0
# Score    1
# Extra    0
# dtype: int64

# %%
df.drop(5, inplace=True)
df
# Out:
#      Name   Age       City  Score Extra
# 0   Alice    25      Delhi   85.0     x
# 1     Bob    30     Mumbai    NaN     y
# 2  Chrlie  None        Pun   78.0     z
# 3   David    40  Bangalore   88.0     x
# 4   Alice    25      Delhi   85.0     y

# %%
print(df['Age'].dtype)
df['Age'] = df['Age'].astype('Int32')
print(df['Age'].dtype)
print(df['Age'])
# Out:
# object
# Int32
# 0      25
# 1      30
# 2    <NA>
# 3      40
# 4      25
# Name: Age, dtype: Int32

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    30
# 3    40
# 4    25
# Name: Age, dtype: Int32

# %%
df['Score']
# Out:
# 0    85.0
# 1     NaN
# 2    78.0
# 3    88.0
# 4    85.0
# Name: Score, dtype: float64

# %%
df['Score'] = df['Score'].fillna(df['Score'].mean())

# %%
df
# Out:
#      Name  Age       City  Score Extra
# 0   Alice   25      Delhi   85.0     x
# 1     Bob   30     Mumbai   84.0     y
# 2  Chrlie   30        Pun   78.0     z
# 3   David   40  Bangalore   88.0     x
# 4   Alice   25      Delhi   85.0     y

# %%
#replace values 
df
# Out:
#      Name  Age       City  Score Extra
# 0   Alice   25      Delhi   85.0     x
# 1     Bob   30     Mumbai   84.0     y
# 2  Chrlie   30        Pun   78.0     z
# 3   David   40  Bangalore   88.0     x
# 4   Alice   25      Delhi   85.0     y

# %%
df['City'] = df['City'].replace('Pun','Pune')

# %%
df
# Out:
#      Name  Age       City  Score Extra
# 0   Alice   25      Delhi   85.0     x
# 1     Bob   30     Mumbai   84.0     y
# 2  Chrlie   30       Pune   78.0     z
# 3   David   40  Bangalore   88.0     x
# 4   Alice   25      Delhi   85.0     y

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.drop('Extra', axis=1, inplace=True)

# %%
df
# Out:
#      Name  Age       City  Score
# 0   Alice   25      Delhi   85.0
# 1     Bob   30     Mumbai   84.0
# 2  Chrlie   30       Pune   78.0
# 3   David   40  Bangalore   88.0
# 4   Alice   25      Delhi   85.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      Int32
#  2   City    5 non-null      object
#  3   Score   5 non-null      float64
# dtypes: Int32(1), float64(1), object(2)
# memory usage: 277.0+ bytes
