# %%
#mean/average
age = [28,56,35,28,76,89]
#manually
a = (28+56+35+28+76+89)/6
print(a)
# Out:
# 52.0

# %%
#using libraries
import numpy as np
np.mean(age)
# Out:
# 52.0

# %%
heights = [160,120,125,140]
np.mean(heights)
# Out:
# 136.25

# %%
#median
nos = [4,2,5,7,2]
np.median(nos)
# Out:
# 4.0

# %%
#mode
nos = [3,2,4,5,3,5,3]
np.mode(nos) #it will gives error because numpy doesnot have mode funtion
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 #mode
#       2 nos = [3,2,4,5,3,5,3]
# ----> 3 np.mode(nos)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
#we need to import stats from scipy
from scipy import stats
stats.mode(nos)
# Out:
# ModeResult(mode=3, count=3)

# %%
#we can also import statistics 
import statistics as st
st.mode(nos)
# Out:
# 3

# %%
st.mean(nos)
# Out:
# 3.5714285714285716

# %%
st.median(nos)
# Out:
# 3

# %%
#how outlier effect mean and doesnot effect median
height = [120,150,180,210,1000]
print(st.mean(height))
print(st.median(height))
#here mean value increase becuase of outlier but median will give proper
#because mean works on values and median works on positions
# Out:
# 332
# 180

# %%
# Out:
# 120
