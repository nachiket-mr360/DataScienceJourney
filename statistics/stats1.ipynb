# %%
data = [1,2,3,4,5]
data
# Out:
# [1, 2, 3, 4, 5]

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
np.mean(data)
# Out:
# 3.0

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
np.mean(df['tip'])
# Out:
# 2.99827868852459

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
np.median(data)
# Out:
# 3.0

# %%
np.median(df['tip'])
# Out:
# 2.9

# %%
#mean is infliated by outlier whereas median is not inflated
data = [1,2,3,4,5,100]
np.mean(data)
# Out:
# 19.166666666666668

# %%
np.median(data)
# Out:
# 3.5

# %%
data = [1,2,1,100,100,3,5,78]
#in numpy we don't have mode operation so we import statics
import statistics
statistics.mode(data)
# Out:
# 1

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#to know parsentile
np.percentile(data, [25])
# Out:
# array([1.75])

# %%
np.percentile(data, [25,50,75,100])
# Out:
# array([  1.75,   4.  ,  83.5 , 100.  ])

# %%
#when we add outliers
data.extend([600, 800])

# %%
#outlier detection using boxplot
sns.boxplot(data)
# Out:
# <Axes: >

# %%
#calculate variance and std
np.var(data)
# Out:
# 74051.4

# %%
np.std(data)
# Out:
# 272.1238688538732

# %%
np.mean(data)
# Out:
# 169.0

# %%
#using statistics library
print(statistics.mean(data))
print(statistics.variance(data)) #it will give for sample 
print(statistics.pvariance(data))
print(statistics.stdev(data)) #for sample
print(statistics.pstdev(data))
# Out:
# 169
# 82279.33333333333
# 74051.4
# 286.84374375839775
# 272.12386885387326

# %%
import math 
math.sqrt(statistics.pvariance(data))
# Out:
# 272.1238688538732

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#correlations
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.select_dtypes('number').corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
corr = df.corr(numeric_only=True)
#hitmap used to represent the correlation values
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
df.cov(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
sns.pairplot(df) #give relationship of all the variables.

# %%
#distibution plot
data
# Out:
# [1, 2, 1, 100, 100, 3, 5, 78, 600, 800]

# %%
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data, kde=True) #kde karnul density estimation, it give shape of distribution
# Out:
# <Axes: ylabel='Count'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(df['total_bill'], kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#if we want probability distribution in y-axis instead of count
sns.distplot(df['total_bill'])
# Out:
# C:\Users\nachi\AppData\Local\Temp\ipykernel_14592\2910304760.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#generate data with normal distribution
df1 = np.random.normal(0.5, 0.2, 1000)
#np.random.normal(mean, std, datapoints)
df1
# Out:
# array([ 0.49567593,  0.41278424,  0.6187829 ,  0.52600804,  0.35920339,
#         0.80417862,  0.59750966,  0.76537843,  0.62930492,  0.40172764,
#         0.9579993 ,  0.55797329,  0.37627365,  0.43143545,  0.18245224,
#         0.53996897,  0.31028089,  0.62108759,  0.66107922,  0.40785636,
#         0.78711105,  0.1916825 ,  0.32890108,  0.46820901,  0.55599048,
#         0.44728606,  0.65896899,  0.5499311 ,  0.38954499,  0.47459599,
#         0.52175809,  0.56342011,  0.43601783,  0.60024712,  0.68397739,
#         0.56323983,  0.41431928,  0.7904279 ,  0.41083874,  0.22036766,
#         0.65741831,  0.7395526 ,  1.02228395,  0.73606065,  0.18497776,
#         0.61995932,  0.45724262,  0.45331101,  0.364449  ,  0.66206849,
#         0.76127041,  0.1936147 ,  0.5363961 ,  0.24066388,  0.19441952,
#         0.69640346,  0.55929022,  0.19960901,  0.24729157,  0.65611484,
#         0.68196705,  0.27625846,  0.5089526 ,  0.91371158,  0.60916949,
# ...

# %%
sns.histplot(df1, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.displot(df1, kde=True)
