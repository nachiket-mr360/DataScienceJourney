# %%
#data strucute are type of storage which stores multiple values
#in python we have list, tuples, dictionary, and set data structure to store things
#list data structure 
a = {21,3,54}

# %%
#list:
'''
when we want to store multiple values in a variable we use list
syntax of list
a = [elemt1, elemt2, ..., elemtn]
we use square backets ([]) to store values
indexing in list (similar to strong)
slicing in list (similar to strings)
list are heterogenous in nature (can store multiple data structure)
mutable nature (can change any values)
deep copy and shallow copy in repect to data structure
'''
a = [] #empty list
print(type(a))
# Out:
# <class 'list'>

# %%
#heterogenous
a = [12, 23.43, 'nachiket', True, 'a', 12j, print(), str()]
#you can store anything inside a list
print(a)
# Out:
# [12, 23.43, 'nachiket', True, 'a', 12j, None, '']

# %%
#list can also store duplicates 
a = [2,2,5,3,2,4,5,]
print(a)
# Out:
# [2, 2, 5, 3, 2, 4, 5]

# %%
#list is mutable
a = [3,4,2,4,6,4]
print(a[0])
a[0] = 49
print(a[0])
# Out:
# 3
# 49

# %%
#indesing in list (similar to string)

s = 'nature'
print(s[0])
print(s[0:4])
# Out:
# n
# natu

# %%
l = [10,20,30,40,50]
print(l[0])
print(l[-1])
print(l[-3])
# Out:
# 10
# 50
# 30

# %%
#slicing in list (similar to string)
print(l[0:])
print(l[:5])
print(l[::])
print(l[0:10:2])
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 30, 50]

# %%
#deep and shallow copy
a = [10,20,30,40,50]
b = a #reference copy (location)
#change in either of them effect both
b[0] = 100
print(a,b)
# Out:
# [100, 20, 30, 40, 50] [100, 20, 30, 40, 50]

# %%
#shallow copy
a = [10,20,30,40,50]
b = a.copy()
b[0] = 100
print(a,b) #change in b doesnot effect the a
# Out:
# [10, 20, 30, 40, 50] [100, 20, 30, 40, 50]

# %%
#we can use deep copy as
import copy
a = [1,3,4,5,6]
b = copy.deepcopy(a)
b[0] = 100
print(a,b)
# Out:
# [1, 3, 4, 5, 6] [100, 3, 4, 5, 6]

# %%
#list traversing
a = [10,20,30,40]
for i in a:
    print(i) #targeting the elements
# Out:
# 10
# 20
# 30
# 40

# %%
#traversing method 2
a = [10,20,30,40]
for i in range(len(a)):
    print(i) #targeting indexes
# Out:
# 0
# 1
# 2
# 3

# %%
#list methods 
help(list)
#get all methods information
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
#append funtion
a = [10,20,30,40]
a.append(50)
a
# Out:
# [10, 20, 30, 40, 50]

# %%
#clear funtion
a = [10,20,30,40]
a.clear()
a
# Out:
# []

# %%
#count
a = [10,20,30,40, 20]
a.count(20) #get count of occurance
# Out:
# 2

# %%
#index
a = [10,20,30,40]
print(a[0])
print(a[-1])
print(a[0:])
print(a[:3])
# Out:
# 10
# 40
# [10, 20, 30, 40]
# [10, 20, 30]

# %%
#sum and avarage of list
#create a list of numbers , then calculate and print the total sum and average
li = [1,3,4,9,2]
total = 0
average = 0
for i in li:
    total +=i
print(f'sum is {total}\naverage is {total/len(li)}')
# Out:
# sum is 19
# average is 3.8

# %%
#maximum element with index
#find the largest element in the list along with its position(index)
li = list(map(int, input().split()))
largest = li[0]
for i in li:
    if i > largest:
        largest =i
print(largest, li.index(largest))
# Out:
# 45 5

# %%
#or
li = list(map(int, input().split()))

largest = li[0]
index = 0
for i in range(len(li)):
    if li[i] > largest:
        largest = li[i]
        index = i
print(largest)
print(index)
# Out:
# 43
# 4

# %%
#2nd greatest element

li=list(map(int, input().split()))

largest = li[0]
sec_largerst = li[0]
index = 0
index2 = 0

for i in range(len(li)):
    if li[i] > largest:
        sec_largerst = largest
        index2 = index
        index =i
        largest = li[i]
print(sec_largerst, index2)
# Out:
# 44 1

# %%
#check if list is sorted #varify whether the list elements are ascending order
li = list (map(int, input().split()))

for i in range(len(li)-1):
    if a[i] < a[i+1]:
        continue
    else:
        print('not sorted')
else:
    print('list is sorted')
# Out:
# list is sorted

# %%
#left rotation by 1
#shift all elements one position to the left , with the first element moving to the end

li = list(map(int, input().split()))

for i in range(len(li)-1):
    li[i], li[i+1] = li[i+1], li[i]

print(li)
# Out:
# [20, 30, 40, 10]

# %%
#left rotation by 1
#shift all elements one position to the right , with the first element moving to the end

li = list(map(int, input().split()))

for i in range(len(li)-1, 0, -1):
    li[i], li[i-1] = li[i-1], li[i]

print(li)
# Out:
# [50, 10, 20, 30, 40]

# %%
#rotate elements k times
k = int(input("enter how many rotations you want: "))
li = list(map(int, input("enter elements of list: ").split()))

for i in range(k):
    for i in range(len(li)-1):
        li[i], li[i+1] = li[i+1], li[i]
print(li)
# Out:
# [4, 5, 6, 2, 3]

# %%
#reverse list, without using inbuilds

li = [10,20,30,40,50]
b = len(li)-1

for i in range(len(li)//2):
    li[i], li[b] = li[b], li[i]
    b = b-1
print(li)
# Out:
# [50, 40, 30, 20, 10]

# %%
#linear search 

li = list(map(int, input().split()))
key = int(input("enter search key: "))

for i in range(len(li)):
    if li[i] == key:
        print(f'key found at {i} index')
        break
else:
    print('key not found')
#linear search has time complecity t(o)
# Out:
# key found at 6 index

# %%
#binary search
#efficiently search in sorted list, using divide and conque
li = list(map(int, input("enter list element in sorted order").split()))

for i in range(len(li)-1):
    if li[i] < li[i+1]:
        continue
    else:
        print("list is not sorted you can't perform binary search")
        break
else:
    print('list is sorted, you can perform binary search ')
    key = int(input('enter search key: '))
    
    start = 0
    end = len(li)-1
    mid = (start+end)//2
    
    while start <= end:
        if li[mid] == key:
            print(f'element found at {mid} index')
            break
        elif li[mid] > key:
            end = mid-1
            mid = (start+end)//2
        elif li[mid] < key:
            start = mid+1
            mid = (start+end)//2
    else:
        print('no such element exists')
# Out:
# list is sorted, you can perform binary search
# no such element exists

# %%
#bubble sort

li = list(map(int, input().split()))

for i in range(len(li)-1):
    for j in range(len(li)-1-i):
        if li[j] >li[j+1]:
            li[j], li[j+1] = li[j+1], li[j]
print(li)
# Out:
# [1, 1, 1, 2, 2, 3, 3, 3, 5]

# %%
#selection sort

# %%
#replace even number with zero
def replace_even_with_zero(lst):
    for i in range(len(lst)):
        if lst[i] %2 ==0:
            lst[i] =0
    return lst
replace_even_with_zero([3,3,5,2,6,3,2])
# Out:
# [3, 3, 5, 0, 0, 3, 0]

# %%
#slit list into 3 halfs , if odd then len(list1) > len(list2)
def split_list_in_halves(numbers):

    mid = (len(numbers)+1)//2
    first_half = numbers[:mid]
    second_half = numbers[mid:]

    return first_half, second_half

split_list_in_halves([4,5,2,5,1])
# Out:
# ([4, 5, 2], [5, 1])

# %%
def remove_specific_element(numbers, x):
    for i in range(len(numbers)):
        if numbers[i] == x:
            numbers.remove(x)
            
            return numbers
    else:
        return numbers
remove_specific_element([2,3,4,5],1)
remove_specific_element([2,4,5,2,4],2)
# Out:
# [4, 5, 2, 4]

# %%
#count element above the average in list
def count_elements_above_average(numbers):
    average = 0
    total = 0
    count = 0
    for i in range(len(numbers)):
        total += numbers[i]
    average = total/len(numbers)
    for i in range(len(numbers)):
        if numbers[i] > average:
            count +=1
    return count

count_elements_above_average([4,2,4,1,9,8])
# Out:
# 2

# %%
def product_of_list_elements(numbers):
    product = 1
    for i in range(len(numbers)):
        product *= numbers[i]
    return product

product_of_list_elements([3,4,5,1,4])
# Out:
# 240

# %%
def print_unique_elements(numbers):
    start = 0
    for i in range(len(numbers)-1):
        if numbers[i] == numbers[i+1]:
            numbers.remove(numbers[i])
    return numbers
print_unique_elements([2,4,2,5,7,4])
# Out:
# [2, 4, 2, 5, 7, 4]

# %%
l = [1,3,4,5,6]
l.pop(2)
# Out:
# 4

# %%
def sum_of_list_elements(numbers):
    # Write your code here
    total = 0
    for i in range(len(numbers)):
        total += numbers[i]
    return total

# %%
def find_two_greatest(numbers):
    # Write your code here
    first = numbers[0]
    second = numbers[1]

    for i in range(len(numbers)):
        if numbers[i] > first:
            second = first
            first = numbers[i]
        elif numbers[i] > second and numbers[i] != first:
            second = numbers[i]
    if first == second:
        return first,
    else:

        return first, second

find_two_greatest([9,8,9])
# Out:
# (9, 8)

# %%
#tuples
#we use () to store tuples
a = (1,1.2,'hello', print(), True) #heterogenous
#a[0] = 't' #tuples are immutable we can't change it's values
#it can store duplicate values also
a
# Out:
# (1, 1.2, 'hello', None, True)

# %%
#tuple unpacking
a,b,c = (10,20,30) #here a get 10, b get 20, c get 30 this is called tuple unpacking
print(a,b,c)
# Out:
# 10 20 30

# %%
a = ()
print(type(a)) #tuple
b = (1) 
print(type(b)) #not a tuple we need to provide , for make it tuple
c = (1,)
print(type(c))
# Out:
# <class 'tuple'>
# <class 'int'>
# <class 'tuple'>

# %%
#tuples indexing and slicing are same as string and list
a = [10,20,30,40]
print(a[0])
print(a[-1])
print(a[0:])
print(a[:4])
# Out:
# 10
# 40
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
#list to tuple
a = [10,20,30,40]
tup = tuple(a)
print(tup, type(tup))
# Out:
# (10, 20, 30, 40) <class 'tuple'>

# %%
#traversing 
#on basis of values
a = (10,20,30,40)
for i in a:
    print(i) #direct access
# Out:
# 10
# 20
# 30
# 40

# %%
#basis of index
for i in range(len(a)):
    print(i, a[i])
# Out:
# 0 10
# 1 20
# 2 30
# 3 40

# %%
#tuple methods
#there are only 2 methods in tuples 
help(tuple)
# Out:
# Help on class tuple in module builtins:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...

# %%
#count
print(a.count(10)) #count how many occurance of 10
a.index(30)
# Out:
# 1
# 2

# %%
def sum_and_average_tuple(n, elements):
    total = 0
    average = 0
    for i in elements:
        total +=i

    average = total/n
    print(f'Sum: {total}\nAverage: {average}')

sum_and_average_tuple(4, (3,4,5,6))
# Out:
# Sum: 18
# Average: 4.5

# %%
def remove_element_from_tuple(n, elements, to_remove):

    for i in elements:
        if i == to_remove:
            elements.remove(i)

    return tuple(elements)

remove_element_from_tuple(3,[13,4,5], 4)
# Out:
# (13, 5)

# %%
def check_element_existence(elements, search_element):
    
    for i in elements:
        if i == search_element:
            return 'Found'
            break
    else:
        return 'Not Found'

check_element_existence((4,5,6,7,20), 4)
# Out:
# 'Found'

# %%
def max_min_tuple_elements( elements):
    return max(elements), min(elements)
    print(f'Maximum: {max(elements)}\nMinimum: {min(elements)}')

#or 
max_min_tuple_elements((3,4,5,6,4,7))
# Out:
# (7, 3)

# %%
def max_min_tuple_elements(elements):
    
    min_ele = elements[0]
    max_ele = elements[0]
    for i in elements:
        if i > max_ele:
            max_ele = i
        elif i < min_ele:
            min_ele = i
    return max_ele, min_ele
    print(f'Maximum: {max_ele}\nMinimum: {min_ele}')
max_min_tuple_elements((3,4,5,6,4,7))
# Out:
# (7, 3)

# %%
#sets , it's represented using {}

s = {10,20,30,40,50}
print(type(s))
# Out:
# <class 'set'>

# %%
#we can only store hashable values inside set. ex:
print(hash('hello'))
print(hash(1234)) #hash of number are same
#print(hash([1,2,3])) #list and sets can't be converted in hash
#we can hash int, string, tuple, float, boolean, funtion

s = {10,'hello', (1,2,3),True, 1.3, print()}
print((s))
# Out:
# -8501310113618180332
# 1234
#
# {None, True, 1.3, 10, (1, 2, 3), 'hello'}

# %%
#set's remove duplicate values, because it has unordered natured

s = {10,20,30,40,50}
print(s)
# Out:
# {50, 20, 40, 10, 30}

# %%
#set convert it's elements into hash values, and inside our ram (a ram which a space),
#it assign things according to hash's slot (which hash value has first slot that took place first)

#you can't have duplicate values
s1 = {10,10,20,30,40,40,40,30}
print(s1)

#why we can't store duplicate values in set
#one element has only single hash value, when that value space is already occupied we can't add another
#so it remove duplicates and store single value
# Out:
# {40, 10, 20, 30}

# %%
#due to not having order , we can't apply indexing or slicing
#set constructor

a = [12,12,3,4,54,54,2,4,5,2,4,5]
s = set(a)
print(s)
# Out:
# {2, 3, 4, 5, 12, 54}

# %%
#set traversing, (traversing is basis of hash value )
s = {23,44,5,6,6,5,3,20}

for i in s:
    print(i) #it gives random numbers according to hash
# Out:
# 3
# 20
# 5
# 6
# 23
# 44

# %%
#set methods (set has semi mutable in nature means we can apply methods and perform operations
# but basically it's immutable)
s = {10,20,30,40}
s.add(70) #add 70
print(s)
# Out:
# {70, 40, 10, 20, 30}

# %%
s1 = {10,20,30,40}
s2 = {30,40,50,60}

print(s1.difference(s2)) # or s1 - s2
# Out:
# {10, 20}

# %%
#discard (remove specific items) or remove
s = {10,20,30,40}
s.discard(30)
s
# Out:
# {10, 20, 40}

# %%
#intersection
s1 = {10,20,30,40}
s2 = {30,40,50,60}
print(s1 & s2) #or 
print(s1.intersection(s2))
#union
print(s1 | s2) #or 
print(s1.union(s2))
# Out:
# {40, 30}
# {40, 30}
# {40, 10, 50, 20, 60, 30}
# {40, 10, 50, 20, 60, 30}

# %%
s1 = {10,20,30,40}
s2 = {30,40,50,60}
s3 = {10,30}

s3.issubset(s1)
# Out:
# False

# %%
s1.pop() #delete 1 element
# Out:
# 40

# %%
#symmentric difference #remove comman elements
print(s1.symmetric_difference(s2)) # or
print(s1^s2)
# Out:
# {40, 10, 50, 20, 60}
# {40, 10, 50, 20, 60}

# %%
s = [193,4,2,4,4]
s.sort()
s
# Out:
# [2, 4, 4, 4, 193]
